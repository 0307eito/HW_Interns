# %% [markdown]
# # OpenStreetMap
# 作業內容：嘗試用 Overpass API ，在自己的 Juptyer Notebook 中，使用如 Folium 或是其他地圖套件載入你感興趣的商家或設施。
#
# ## 全台灣釣具行分佈

# %%
import requests
import json
import folium
import overpass

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# 您可以根據需求修改這裡的查詢條件
overpass_query = """
[out:json];
node
  ["shop"="fishing"]
  (21.8,119.5,25.4,122.0);
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
m = folium.Map(location=[23.7, 121.0], zoom_start=8)

# 遍歷 Overpass API 的回應資料，並將每個點標記在地圖上
for element in data['elements']:
    lat = element['lat']
    lon = element['lon']
    name = element.get('tags', {}).get('name', 'Fishing Port')
    
    folium.Marker(
        location=[lat, lon],
        popup=name,
        icon=folium.Icon(icon='info-sign')
    ).add_to(m)

# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a0b87f2a04c2172e8f3e7ac640b0509 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a0b87f2a04c2172e8f3e7ac640b0509&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a0b87f2a04c2172e8f3e7ac640b0509 = L.map(
#                 &quot;map_9a0b87f2a04c2172e8f3e7ac640b0509&quot;,
#                 {
#                     center: [23.7, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebe66ac647c7b278d45a4b7d8dbe22c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ebe66ac647c7b278d45a4b7d8dbe22c3.addTo(map_9a0b87f2a04c2172e8f3e7ac640b0509);
#
#
#             var marker_3a3e5617610a24a23f6354af7e7e055d = L.marker(
#                 [24.2616745, 120.8136783],
#                 {}
#             ).addTo(map_9a0b87f2a04c2172e8f3e7ac640b0509);
#
#
#             var icon_60aada440d94cd66812944a86e9030d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a3e5617610a24a23f6354af7e7e055d.setIcon(icon_60aada440d94cd66812944a86e9030d3);
#
#
#         var popup_73484d58510221e7bc09a7e5c77252b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11cc6204f83fe2d3b827a9f11cef0102 = $(`&lt;div id=&quot;html_11cc6204f83fe2d3b827a9f11cef0102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大統釣具店&lt;/div&gt;`)[0];
#                 popup_73484d58510221e7bc09a7e5c77252b9.setContent(html_11cc6204f83fe2d3b827a9f11cef0102);
#
#
#
#         marker_3a3e5617610a24a23f6354af7e7e055d.bindPopup(popup_73484d58510221e7bc09a7e5c77252b9)
#         ;
#
#
#
#
#             var marker_7ed886bed0e8cf5935569fdd509d479e = L.marker(
#                 [22.6271435, 120.344182],
#                 {}
#             ).addTo(map_9a0b87f2a04c2172e8f3e7ac640b0509);
#
#
#             var icon_6d5a13e823572cb37dafc7823262f545 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ed886bed0e8cf5935569fdd509d479e.setIcon(icon_6d5a13e823572cb37dafc7823262f545);
#
#
#         var popup_f30747bceb8ac597f7924bd3718911d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab1743fe482b24d93db253ba93530b86 = $(`&lt;div id=&quot;html_ab1743fe482b24d93db253ba93530b86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;魚拓釣具&lt;/div&gt;`)[0];
#                 popup_f30747bceb8ac597f7924bd3718911d1.setContent(html_ab1743fe482b24d93db253ba93530b86);
#
#
#
#         marker_7ed886bed0e8cf5935569fdd509d479e.bindPopup(popup_f30747bceb8ac597f7924bd3718911d1)
#         ;
#
#
#
#
#             var marker_f83f00dde4983546ba6aeebc97b92ca7 = L.marker(
#                 [25.0195827, 121.4662673],
#                 {}
#             ).addTo(map_9a0b87f2a04c2172e8f3e7ac640b0509);
#
#
#             var icon_c22e5d45bc15ff3756f36bbca65b692e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f83f00dde4983546ba6aeebc97b92ca7.setIcon(icon_c22e5d45bc15ff3756f36bbca65b692e);
#
#
#         var popup_34e445936564c2b4b97f255a215e2a99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_216ce31f19b111cb5253fb8879b55a1c = $(`&lt;div id=&quot;html_216ce31f19b111cb5253fb8879b55a1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;永濱釣具行&lt;/div&gt;`)[0];
#                 popup_34e445936564c2b4b97f255a215e2a99.setContent(html_216ce31f19b111cb5253fb8879b55a1c);
#
#
#
#         marker_f83f00dde4983546ba6aeebc97b92ca7.bindPopup(popup_34e445936564c2b4b97f255a215e2a99)
#         ;
#
#
#
#
#             var marker_1d6ed2c73fa670fcbfc23d621bbaf73a = L.marker(
#                 [22.8079078, 120.2429556],
#                 {}
#             ).addTo(map_9a0b87f2a04c2172e8f3e7ac640b0509);
#
#
#             var icon_ac4d004b690d0bc93913b91604518ce4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &qu
